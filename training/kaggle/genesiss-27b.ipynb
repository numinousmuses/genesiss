# %% [markdown]
# # genesiss-27b — Kaggle
#
# Kaggle's largest free GPU (P100, T4 ×2) cannot fit a Qwen 3.5 27B LoRA even in 16-bit. Use the Colab H100 notebook at `training/colab/genesiss-27b.ipynb`.
